# %% [markdown]
# ## Remove Irrelevant Columns

# %%
import pandas as pd

# %%
PATH_TO_CSV = "../data/raw/raw_cleaned/final_test.csv"

# %%
df = pd.read_csv(PATH_TO_CSV)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 33 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0.1  100000 non-null  int64
#  1   Unnamed: 0    100000 non-null  int64
#  2   user id       100000 non-null  int64
#  3   movie id      100000 non-null  int64
#  4   rate          100000 non-null  int64
#  5   timestamp     100000 non-null  int64
#  6   datetime      100000 non-null  object
#  7   age           100000 non-null  object
#  8   gender        100000 non-null  object
#  9   occupation    100000 non-null  object
#  10  zip code      100000 non-null  object
#  11  movie title   100000 non-null  object
#  12  IMDb URL      100000 non-null  object
#  13  Other         100000 non-null  int64
#  14  Action        100000 non-null  int64
#  15  Adventure     100000 non-null  int64
#  16  Animation     100000 non-null  int64
# ...

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  user id  movie id  rate  timestamp  \
# 0             0           0      196       242     3  881250949
# 1             1           1      186       302     3  891717742
# 2             2           2       22       377     1  878887116
# 3             3           3      244        51     2  880606923
# 4             4           4      166       346     1  886397596
#
#               datetime    age gender  occupation  ... Film-Noir Horror  \
# 0  1997-12-04 15:55:49  Adult      M      writer  ...         0      0
# 1  1998-04-04 19:22:22  Adult      F   executive  ...         1      0
# 2  1997-11-07 07:18:36  Adult      M      writer  ...         0      0
# 3  1997-11-27 05:02:03  Adult      M  technician  ...         0      0
# 4  1998-02-02 05:33:16  Adult      M    educator  ...         0      0
#
#   Musical  Mystery  Romance  Sci-Fi  Thriller  War  Western  release_year
# 0       0        0        0       0         0    0        0        1997.0
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'user id', 'movie id', 'rate',
#        'timestamp', 'datetime', 'age', 'gender', 'occupation', 'zip code',
#        'movie title', 'IMDb URL', 'Other', 'Action', 'Adventure', 'Animation',
#        'Children's', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Fantasy',
#        'Film-Noir', 'Horror', 'Musical', 'Mystery', 'Romance', 'Sci-Fi',
#        'Thriller', 'War', 'Western', 'release_year'],
#       dtype='object')

# %%
df_cleaned = df.drop(columns=['Unnamed: 0.1', 'Unnamed: 0', 'user id', 'timestamp', 'zip code', 'IMDb URL'])

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 27 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   movie id      100000 non-null  int64
#  1   rate          100000 non-null  int64
#  2   datetime      100000 non-null  object
#  3   age           100000 non-null  object
#  4   gender        100000 non-null  object
#  5   occupation    100000 non-null  object
#  6   movie title   100000 non-null  object
#  7   Other         100000 non-null  int64
#  8   Action        100000 non-null  int64
#  9   Adventure     100000 non-null  int64
#  10  Animation     100000 non-null  int64
#  11  Children's    100000 non-null  int64
#  12  Comedy        100000 non-null  int64
#  13  Crime         100000 non-null  int64
#  14  Documentary   100000 non-null  int64
#  15  Drama         100000 non-null  int64
#  16  Fantasy       100000 non-null  int64
# ...

# %%
df_cleaned.columns
# Out:
# Index(['movie id', 'rate', 'datetime', 'age', 'gender', 'occupation',
#        'movie title', 'Other', 'Action', 'Adventure', 'Animation',
#        'Children's', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Fantasy',
#        'Film-Noir', 'Horror', 'Musical', 'Mystery', 'Romance', 'Sci-Fi',
#        'Thriller', 'War', 'Western', 'release_year'],
#       dtype='object')

# %%
df_cleaned.head()
# Out:
#    movie id  rate             datetime    age gender  occupation  \
# 0       242     3  1997-12-04 15:55:49  Adult      M      writer
# 1       302     3  1998-04-04 19:22:22  Adult      F   executive
# 2       377     1  1997-11-07 07:18:36  Adult      M      writer
# 3        51     2  1997-11-27 05:02:03  Adult      M  technician
# 4       346     1  1998-02-02 05:33:16  Adult      M    educator
#
#                   movie title  Other  Action  Adventure  ...  Film-Noir  \
# 0                Kolya (1996)      0       0          0  ...          0
# 1    L.A. Confidential (1997)      0       0          0  ...          1
# 2         Heavyweights (1994)      0       0          0  ...          0
# 3  Legends of the Fall (1994)      0       0          0  ...          0
# 4         Jackie Brown (1997)      0       0          0  ...          0
#
#    Horror  Musical  Mystery  Romance  Sci-Fi  Thriller  War  Western  \
# ...

# %%
df_cleaned.to_csv(PATH_TO_CSV, index=False)
